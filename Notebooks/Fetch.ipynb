# %%
import matplotlib.pyplot as plt

# %%
x = [0,1,10]
y = [0,1,1]

def plot_fetch():
    
    fig, axs = subplots(figsize=(8,4))
    axs.plot([0,1],[1,1],'--k')
    axs.plot([1,1],[0,1],'--k')
    axs.plot(x,y,'-k',linewidth=3)
    axs.set_xlim((0,3))
    axs.set_xticks((0,1))
    axs.set_xlabel(r'normalized fetch [$x / F_c$]')
    axs.set_ylim((0,1.5))
    axs.set_yticks((0,1))
    axs.set_ylabel(r'normalized transport rate [$q / q_{eq}(u_*)$]')
    axs.set_aspect('equal')
    
    return (fig, axs)

# %%
fig, axs = plot_fetch();

# %%
fig, axs = plot_fetch();
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

# %%
fig, axs = plot_fetch();
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

# %%
fig, axs = plot_fetch();
axs.set_xticks((0, .75))
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticks((0, .75))
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

x2 = [.75, 10]
y2 = [.75, .75]

axs.plot([0,.75],[.75,.75],'--k')
axs.plot([.75,.75],[0,.75],'--k')
axs.plot(x2,y2,'-g',linewidth=3)
#axs.annotate('reduced equilibrium transport rate', (3,.75), color='g', va='top', ha='right')

# %%
fig, axs = plot_fetch();
axs.set_xticks((0, 1.5))
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

x2 = [0., 1.5]
y2 = [0., 1.]

axs.plot([1.5,1.5],[0,1.],'--k')
axs.plot(x2,y2,'-r',linewidth=3)
axs.annotate('reduced sediment supply', (1.56, 1.), color='r', va='top', ha='right', rotation=np.arctan(1./1.5)/np.pi*180.)

# %%
fig, axs = plot_fetch();
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

x2 = [.75, 10]
y2 = [.75, .75]

axs.plot([0,.75],[.75,.75],'--k')
axs.plot([.75,.75],[0,.75],'--k')
axs.plot(x2,y2,'-g',linewidth=3)

x2 = [0., 1.5]
y2 = [0., 1.]

axs.plot([1.5,1.5],[0,1.],'--k')
axs.plot(x2,y2,'-r',linewidth=3)

# %%
fig, axs = plot_fetch();
axs.set_xticks((0, 1.))
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

x2 = [0., .5, 1., 1.5]
y2 = [0., .5, .5, 1.]

x3 = [0., 1., 1.5]
y3 = [0., 1., 1.]

axs.plot([.55, .96],[.01, .01],'-k',linewidth=10)
#axs.plot([.55+.5, .96+.5],[.01, .01],'-k',linewidth=10)
axs.plot([0.,.5],[.5,.5],'--k')
axs.plot([.5,.5],[.5,0.],'--k')

# %%
fig, axs = plot_fetch();
axs.set_xticks((0, 1.5))
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

x2 = [0., .5, 1., 1.5]
y2 = [0., .5, .5, 1.]

axs.plot([.55, .96],[.01, .01],'-k',linewidth=10)
axs.plot([0.,.5],[.5,.5],'--k')
axs.plot([.5,.5],[.5,0.],'--k')
axs.plot([1.5,1.5],[0,1.],'--k')
axs.plot(x2,y2,'-b',linewidth=3)

# %%
fig, axs = plot_fetch();
axs.set_xticks((0, 1.))
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

x3 = [0., 1., 1.5]
y3 = [0., 1., 1.]

axs.plot([.55+.5, .96+.5],[.01, .01],'-k',linewidth=10)
axs.plot([1.5,1.5],[0,1.],'--k')
axs.plot(x3,y3,'-b',linewidth=3)

# %%
fig, axs = plot_fetch();
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

x2 = [.75, 10]
y2 = [.75, .75]

#axs.plot([0,.75],[.75,.75],'--k')
#axs.plot([.75,.75],[0,.75],'--k')
#axs.plot(x2,y2,'-g',linewidth=3)
#axs.annotate('reduced equilibrium transport rate', (3,.75), color='g', va='top', ha='right')

x3 = [0, .5, .8, 10]
y3 = [0, .1, .4, .5]

axs.plot([0,.9],[.4,.4],'--k')
axs.plot([.8,.8],[0,.4],'--k')
axs.plot(x3,y3,'-r',linewidth=3)
axs.annotate('supply-limited transport rate', (3,.5), color='r', va='top', ha='right')

# %%
fig, axs = plot_fetch();

x2 = [0,.75,10]
y2 = [0,.5,.5]

axs.plot([0,.75],[.5,.5],'--k')
axs.plot([.75,.75],[0,.5],'--k')
axs.plot(x2,y2,'-g',linewidth=3)

axs.set_xticks((0,.75,1))
axs.set_xticklabels((0, 'critical supply', '\ncritical fetch'), size=12)
axs.set_xlabel('')

axs.set_yticks((0,.5,1))
axs.set_yticklabels((0, 'maximum supply\n', 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

# %%
fig, axs = plot_fetch();
axs.set_xticklabels((0, 'critical fetch'), size=12)
axs.set_xlabel('')
axs.set_yticklabels((0, 'equilibrium transport'), rotation=90, size=12)
axs.set_ylabel('')

# %%
fig, axs = plot_fetch();

axs.plot([1.25,1.25],[0,1.5],'-g',linewidth=3)
axs.plot([0.75,0.75],[0,1.5],'-',color=(1,.5,0),linewidth=3)
axs.plot([0.5,0.5],[0,1.5],'-r',linewidth=3)

# %%
fig, axs = plot_fetch();

x2 = [0,1.5,3]

axs.plot([1.5,1.5],[0,1],'--r')
axs.plot(x2,y,'-r',linewidth=3)
axs.set_xticks((0,1,1.5))
axs.set_xticklabels((0,1,'')) #'$F_{c,new}$'))
axs.plot([1.25,1.25],[0,1.5],'-g',linewidth=3)

# %%
fig, axs = plot_fetch();
x2 = [0,1.5,3]
axs.plot([.75,.75],[0,1.5],'-g',linewidth=3)
axs.set_xticklabels([0,'$F_c$'])
axs.set_xlabel('fetch [$x$]')
axs.set_xlim((0,2))

fig, axs = plot_fetch();
x2 = [0,1.5,3]
axs.plot([2*.75,2*.75],[0,1.5],'-g',linewidth=3)
axs.set_xticklabels([0,'$F_c$'])
axs.set_xlabel('fetch [$x$]')
axs.set_xlim((0,4))
# Out:
# (0, 4)

# %%
fig, axs = plot_fetch();

#x3 = np.linspace(0,1,100)
#y3 = x3+.1*np.sin(10*np.pi*x3)

n = 30
a = .25

rnd = np.random.random((n,1))
x3 = np.cumsum(rnd) / np.sum(rnd)

rnd = np.random.random((n,1))
y3 = x3+a*(.5-rnd.flatten())

x3[0] = y3[0] = 0
x3[-1] = y3[-1] = 1

axs.plot(x3,y3,'-r',linewidth=3)
axs.plot([1,3],[1,1],'-r',linewidth=3)

# %%
fig, axs = plot_fetch();

#x3 = np.linspace(0,.5,50)
#y3 = x3+.1*np.sin(10*np.pi*x3)

#x4 = np.linspace(.5,1,50)
#y4 = .365+.25*x4+.05*np.sin(10*np.pi*x4)

n = 15
a = .25

rnd = np.random.random((n,1))
x3 = np.cumsum(rnd) / np.sum(rnd) / 2
x3[0] = 0
x3[-1] = .5

rnd = np.random.random((n,1))
y3 = x3+a*(.5-rnd.flatten())
y3[0] = 0
y3[-1] = .5

a = .25

rnd = np.random.random((n,1))
x4 = .5 + np.cumsum(rnd) / np.sum(rnd) / 2
x4[0] = .5
x4[-1] = 1

rnd = np.random.random((n,1))
y4 = .365+.25*x4+a*(.5-rnd.flatten())
y4[0] = .5
y4[-1] = .615

axs.plot([1/.615,1/.615],[0,1],'--r')
axs.plot(x3,y3,'-r',linewidth=3)
axs.plot(x4,y4,'-r',linewidth=3)
axs.plot([1,1/.615],[.615,1],'--r',linewidth=3)
axs.plot([1/.615,3],[1,1],'-r',linewidth=3)

axs.set_xticks((0,1,1/.615))
axs.set_xticklabels((0,1,'')) #'$F_{c,new}$'))

# %%
from copy import deepcopy

def add_jump(axs, x, x0, h, w, n, level=0, cutoff=False, offspring=None, criticalfetch=1000):
    
    if x0 < criticalfetch:
        h = np.random.uniform(h, 3*h)
    else:
        h = np.random.uniform(.8*h, 1.2*h)
        
    w = np.random.uniform(w, 1.5*w)
    
    y = np.sqrt(1 - (2*x - 1)**2) * h * np.sqrt(1-x)
    
    if not cutoff or level < n:
        axs.plot(x0+w*x, y, '-k')
    else:
        axs.plot(x0+w*x[:25], y[:25], '--k')
        axs.scatter(x0+w*x[25], y[25], c='k')
    
    x0 += w*x[-1]
    
    if level < n:
        o = offspring
        if not o:
            o = np.random.randint(1,3)
        for i in range(o):
            add_jump(axs, x, x0, h, w, n, level=level+1, cutoff=cutoff, offspring=offspring, criticalfetch=criticalfetch)
    
    return x0, h, w

x = np.linspace(0,1,100)

# mess
fig, axs = subplots()
for i in range(10):
    add_jump(axs, x, 0, .5, .8, 10, criticalfetch=10)
axs.set_xlim((0,30))
axs.set_ylim((0,100))
axs.set_xticks(())
axs.set_yticks(())
axs.set_xlabel('fetch')
axs.set_ylabel('height above bed')

# small fetches
fig, axs = subplots()
for i in range(10):
    add_jump(axs, x, 0, .5, .8, 5)
axs.set_xlim((0,10))
axs.set_ylim((0,50))
axs.set_xticks(())
axs.set_yticks(())
axs.set_xlabel('fetch')
axs.set_ylabel('height above bed')

# single departing grain
fig, axs = subplots()
add_jump(axs, x, 0, .5, .8, 5)
axs.set_xlim((0,10))
axs.set_ylim((0,50))
axs.set_xticks(())
axs.set_yticks(())
axs.set_xlabel('fetch')
axs.set_ylabel('height above bed')

# single step
fig, axs = subplots()
add_jump(axs, x, 0, .5, .8, 1, cutoff=True, offspring=3)
axs.set_xlim((0,2))
axs.set_ylim((0,2))
axs.set_xticks(())
axs.set_yticks(())
axs.set_xlabel('fetch')
axs.set_ylabel('height above bed')

# %%
x = np.arange(0,3,.1)
plot(1/np.sqrt(2*pi*1**2) * exp(-(x-0)**2)/(2*1**2))

# %%
x = np.arange(0,3,.5)
y = 1/np.sqrt(2*pi*1**2) * exp(-(x-0)**2)/(2*1**2)

x = x[1:]
y = -np.diff(y)
y0 = y.copy()

dy0 = np.array([.06, .04, 0.03, 0., 0.])
dy1 = dy0.copy()

f = 200.

n = 8
m = 5

fig, axs = subplots(n, m, figsize=(10,2*n))

for i in range(n):
    for j in range(m):
    
        ij = i*m+j
    
        if ij == 0:
            axs[i,j].bar(x, y, width=.4)
            axs[i,j].set_title('t = 0; $\overline{D}$=%1.0f' % (np.average(x, weights=y) * f))
        elif np.mod(ij, 2) == 0:
            p2 = axs[i,j].bar(x, dy2, width=.4, color='g', hatch='//')
            axs[i,j].bar(x, y, bottom=dy2, width=.4, color='b')
            y = y + dy2
            
            axs[i,j].set_title('t = %d; $\overline{D}$=%1.0f' % (ij/2, np.average(x, weights=y) * f))
        else:
            dy1 = np.minimum(y, dy0)
            y = y - dy1

            axs[i,j].bar(x, y, width=.4, color='b')
            p1 = axs[i,j].bar(x, dy1, bottom=y, width=.4, color='r', hatch='\\\\')
            axs[i,j].set_title('t = %d; $\overline{D}$=%1.0f' % ((ij+1)/2, np.average(x, weights=y) * f))
            
            dy2 = np.sum(dy1) * y0 / np.sum(y0)
            
        if j == 0:
            axs[i,j].set_ylabel('available mass in\nbed composition\nlayer')
        
        if i == n-1:
            axs[i,j].set_xlabel('sediment fractions')
            
        axs[i,j].set_xticklabels(())
        axs[i,j].set_yticklabels(())
        axs[i,j].set_xlim((.5, 3.))
        axs[i,j].set_ylim((0, .15))
        axs[i,j].grid()
        
axs[-1,-1].legend((p1,p2), ('eroded', 'added from\ndeeper layers'))

# %%
dy0 = np.array([.065, .045, 0.035, 0.02, 0.01])
dy1 = dy0.copy()

n = 4
m = 5

fig, axs = subplots(n, m, figsize=(10,2*n))

for i in range(n):
    for j in range(m):
    
        ij = i*m+j
    
        if ij == 0:
            axs[i,j].bar(x, y, width=.4)
            axs[i,j].set_title('t = 0; $\overline{D}$=%1.0f' % (np.average(x, weights=y) * f))
        elif np.mod(ij, 2) == 0:
            axs[i,j].bar(x, dy2, width=.4, color='g', hatch='//')
            axs[i,j].bar(x, y, bottom=dy2, width=.4, color='b')
            y = y + dy2
            
            axs[i,j].set_title('t = %d; $\overline{D}$=%1.0f' % (ij/2, np.average(x, weights=y) * f))
        else:
            dy1 = np.minimum(y, dy0)
            y = y - dy1

            axs[i,j].bar(x, y, width=.4, color='b')
            axs[i,j].bar(x, dy1, bottom=y, width=.4, color='r', hatch='\\\\')
            axs[i,j].set_title('t = %d; $\overline{D}$=%1.0f' % ((ij+1)/2, np.average(x, weights=y) * f))
            
            dy2 = np.sum(dy1) * y0 / np.sum(y0)
            
        if j == 0:
            axs[i,j].set_ylabel('available mass in\nbed composition layer')
        
        if i == n-1:
            axs[i,j].set_xlabel('sediment fractions')
            
        axs[i,j].set_xticklabels(())
        axs[i,j].set_yticklabels(())
        axs[i,j].set_xlim((.5, 3.))
        axs[i,j].set_ylim((0, .15))
        axs[i,j].grid()
        
axs[-1,-1].legend((p1,p2), ('eroded', 'added from\ndeeper layers'))

# %%
x = np.arange(0,3,.5)
y = 1/np.sqrt(2*pi*1**2) * exp(-(x-0)**2)/(2*1**2)

x = x[1:]
y = -np.diff(y)
y0 = y.copy()

dy0 = np.array([.06, .04, 0.03, 0., 0.])
dy1 = dy0.copy()

f = 200.

n = 4
m = 5

fig, axs = subplots(n, m, figsize=(10,2*n))

for i in range(n):
    for j in range(m):
    
        ij = i*m+j
    
        if ij == 0:
            axs[i,j].bar(x, y, width=.4)
            axs[i,j].set_title('t = 0; $\overline{D}$=%1.0f' % (np.average(x, weights=y) * f))
        elif np.mod(ij, 2) == 0:
            y = y - dy2

            axs[i,j].bar(x, dy2, width=.4, color='r', hatch='\\\\')
            axs[i,j].bar(x, y, bottom=dy2, width=.4, color='b')            
            axs[i,j].set_title('t = %d; $\overline{D}$=%1.0f' % (ij/2, np.average(x, weights=y) * f))
        else:
            axs[i,j].bar(x, y, width=.4, color='b')
            axs[i,j].bar(x, dy0, bottom=y, width=.4, color='g', hatch='//')
            
            y = y + dy0

            axs[i,j].set_title('t = %d; $\overline{D}$=%1.0f' % ((ij+1)/2, np.average(x, weights=y) * f))
            
            dy2 = np.sum(dy0) * y / np.sum(y)
            
        if j == 0:
            axs[i,j].set_ylabel('available mass in\nbed composition layer')
        
        if i == n-1:
            axs[i,j].set_xlabel('sediment fractions')
            
        axs[i,j].set_xticklabels(())
        axs[i,j].set_yticklabels(())
        axs[i,j].set_xlim((.5, 3.))
        axs[i,j].set_ylim((0, .15))
        axs[i,j].grid()
        
axs[-1,-1].legend((p2,p1), ('deposited', 'moved to\ndeeper layers'))

# %%
import matplotlib.patches

fig, axs = subplots(figsize=(8,4))

axs.fill([0, 50, 100, 110, 120, 120], [-5, 0,   0,  10,  10, -5], color=(1,1,.5), edgecolor='k', linewidth=2)
axs.fill([0, 30, 0], [-5, -2, -2], 'b', alpha=.5, edgecolor='none')
axs.fill([0, 45, 0], [-5, -.5, -.5], 'b', alpha=.5, edgecolor='none')

#axs.plot([0, 100, 100, 110, 110, 120], [12, 12, 4, 4, 12, 12], '-.g', linewidth=2)
axs.plot([0, 30, 30, 45, 45, 70, 70, 100, 100, 120], [0, 0, 8, 8, 11.5, 11.5, 11.5, 11.5, 4, 4], '-g', linewidth=2)
axs.plot([0, 30, 30, 45, 45, 70, 70, 100, 100, 120], [0, 0, 0, 6, 6, 6, 6, 7, 4, 4], '-r', linewidth=2)

#axs.annotate('wind transport capacity', (0, 12), xytext=(3,3), textcoords='offset points', color='g')
axs.annotate('equilibrium sediment transport', (45, 11.5), xytext=(3,-2), textcoords='offset points', color='g', va='top')
axs.annotate('sediment transport', (45, 6), xytext=(3,3), textcoords='offset points', color='r')
#axs.annotate('sport', (70, 6), xytext=(5,6), textcoords='offset points', color='r', rotation=8)

axs.annotate('moist', (37.5, -1), color='k', rotation=22.5, ha='center', va='top')
axs.annotate('coarse', (57.5, -.1), color='k', ha='center', va='top')
axs.annotate('fine', (85, -.1), color='k', ha='center', va='top')

axs.annotate('deposition\ndue to bed slope', (100, 4), xytext=(90, -6), color='k', ha='center', va='top',
             arrowprops={'arrowstyle':'->', 'shrinkB':5})
axs.annotate('pick-up of\nsediment', (37.5, 3), xytext=(-10, 0), color='w', ha='center', va='bottom',
             arrowprops={'arrowstyle':'->', 'shrinkB':5})
axs.annotate('pick-up of\nsediment', (80, 6), xytext=(-10, 0), color='k', ha='center', va='bottom',
             arrowprops={'arrowstyle':'->', 'shrinkB':5})
axs.annotate('no sediment availability\ndue to armoring', (57.5, -.5), xytext=(50, -6), color='k', ha='center', va='top',
             arrowprops={'arrowstyle':'->', 'shrinkB':5})

axs.annotate('', (20, 8.5), xytext=(3, 8.5), color='k', ha='left', va='center',
             arrowprops={'arrowstyle':'-|>', 'edgecolor':(.5,.5,.5), 'facecolor':(.5,.5,.5)})
axs.annotate('wind', (20, 9.5), xytext=(3, 9.5), color=(.5,.5,.5), ha='left', va='center',
             arrowprops={'arrowstyle':'-|>', 'edgecolor':(.5,.5,.5), 'facecolor':(.5,.5,.5)})
axs.annotate('', (20, 10.5), xytext=(3, 10.5), color='k', ha='left', va='center',
             arrowprops={'arrowstyle':'-|>', 'edgecolor':(.5,.5,.5), 'facecolor':(.5,.5,.5)})

#axs.add_patch(Rectangle())

axs.set_ylim((-5, 13))

axs.set_xticks((0, 30, 45, 70, 100, 110, 120))
axs.set_xticklabels(())
axs.set_yticks(())
axs.grid()

fig.savefig('/Users/hoonhout/Checkouts/PhD/Conferences/NCK2016/supply.pdf', transparent=False)

# %%
x, y = np.meshgrid(np.linspace(0, 100, 50),
                   np.linspace(0, 1, 20))
x = x.flatten()
y = y.flatten()

s = np.random.randint(1, 10, size=x.shape) * 10.
px = np.random.random(x.shape) * 2.5 - 1.25
py = np.random.random(x.shape) * .05 - .025

x0, x1 = 25, 75
y0, y1 = 0, 1

f = 5.
s = np.minimum(s, f*(x-x0+px))
s = np.minimum(s, f*(x1-x-px))
s = np.minimum(s, 100.*f*(y-y0+py))
s = np.minimum(s, 100.*f*(y1-y-py))
s = np.maximum(s, 0.)

fig, axs = subplots(figsize=(4,4))
axs.scatter(x+px, y+py, s=s, c='k')
axs.set_axis_off()

axs.set_xlim((x0,x1))
axs.set_ylim((0, 1))

fig.savefig('/Users/hoonhout/Checkouts/PhD/Thesis/logo.pdf')

# %%
class Particles:
    
    x = []
    y = []
    vx = []
    vy = []
    inmotion = []
    
    s = []
    
    def __init__(self, n=10, v0=(5., 10.), alpha0=(30., 60.), inmotion=True):
        v0 = self.randomize(v0, n)
        alpha0 = self.randomize(alpha0, n)
        
        self.x = self.randomize((0., 10.), n)
        self.y = self.randomize(0., n)
        self.s = self.randomize((5., 20.), n)
        
        self.vx = v0 * np.cos(alpha0/180.*np.pi)
        self.vy = v0 * np.sin(alpha0/180.*np.pi)
        self.inmotion = self.randomize(inmotion, n)
        
        
    def update(self, dt, a=5., g=-9.81):
        
        ix = self.inmotion
        
        self.x[ix] += self.vx[ix] * dt
        self.y[ix] += self.vy[ix] * dt

        self.vx[ix] += a * dt
        self.vy[ix] += g * dt

        self.y[ix] = np.maximum(0., self.y[ix])

        ix = self.y == 0.
        
        self.vx[ix] = 0.
        self.vy[ix] = 0.
        self.inmotion[ix] = False
            
            
    def plot(self, ax=None):
        if not ax:
            ax = plt.gca()
        ax.scatter(self.x, self.y, s=self.s, c='k')
        
    
    @staticmethod
    def randomize(x, n):
        if type(x) in [list, tuple] and len(x) > 1:
            return np.asarray([x[0] + (x[1] - x[0]) * np.random.random() 
                               for i in range(n)])
        else:
            return np.asarray([x] * n)


        
       
p = Particles(n=100)
            
dt = .1
fig, axs = subplots(figsize=(10,4))
for i in range(20):
    p.plot(ax=axs)
    p.update(dt)
    
axs.set_ylim((0, 5))
axs.set_aspect('equal')
axs.grid()

# %%
x, y = np.meshgrid(np.arange(0, 80, .5),
                   np.arange(0, 3.5, .5))

a = .25
px = a * (np.random.random(x.shape) - .5)
py = a * (np.random.random(x.shape) - .5)

m = 500.
r1 = m * x / x.max() * y / y.max()
r2 = m * x / x.max()
s = np.random.random(x.shape)**2
s = r1 + s * (m - r2)

fig, axs = subplots(figsize=(80,5))
axs.scatter(x+px, y+py, s=s, c='w', edgecolor='w')
axs.set_axis_off()

axs.annotate('unarmored', xy=(.01,1), xycoords='axes fraction',
             fontsize=40, va='bottom', color=(0.,166./255.,214./255.), fontweight='bold')
axs.annotate('armored', xy=(.99,1), xycoords='axes fraction',
             fontsize=40, va='bottom', ha='right', color=(0.,166./255.,214./255.), fontweight='bold')

axs.set_xlim((0, 80))
axs.set_ylim((0, 3.5))
axs.set_aspect('equal')

fig.savefig('/Users/hoonhout/Checkouts/PhD/Conferences/NCK2016/banner_armoring.pdf', transparent=True)

# %%
import os
root = '/Users/hoonhout/Checkouts/PhD/Conferences/NCK2016/'

def plot_bed(x, y, s, fname=None):

    fig, axs = subplots(figsize=(10,4))
    axs.scatter(x, y, s=s, c='k')
    if y[0,0] < y[0,-1]:
        axs.plot([0,80], [-.5,7.5], '-k', linewidth=3)
    else:
        axs.plot([0,80], [7.5,-.5], '-k', linewidth=3)
    axs.set_xticks(())
    axs.set_yticks(())
    axs.set_axis_off()

    axs.set_xlim((0, 80))
    axs.set_ylim((-1,16))
    axs.set_aspect('equal')

    if fname:
        fig.savefig(os.path.join(root, '%s.pdf' % fname))
        
    return fig, axs


random_size = lambda m: m * f * np.random.random(x.shape)
sorted_size = lambda m: m * f * y0 / y0.max()

x, y0 = np.meshgrid(np.arange(0., 80., 1.),
                    np.arange(0., 7., 1.))
y = y0 + .1 * x
y2 = y0 - .1 * x + 8.

a = .5
h = 9.
px = a * (np.random.random(x.shape) - .5)
py = a * (np.random.random(x.shape) - .5)
x += px
y += py
y2 += py

f = 2.
m = 20.
s1 = random_size(m)
plot_bed(x, y, 0., fname='grains_none')
plot_bed(x, y, m/f, fname='grains_small')
plot_bed(x, y, m*f, fname='grains_large')
plot_bed(x, y, s1, fname='grains_random')

s2 = sorted_size(m)
s3 = .25*s1+.75*s2
plot_bed(x, y, s3, fname='grains_sorted')

xl = np.maximum(0., x[:1,:] - 30.) / 50.
s4 = .25*s1 + .75*(1.-xl)*s2
fig, axs = plot_bed(x, y, s4)
fig.savefig(os.path.join(root, 'grains_deposition.pdf'), transparent=True)

xy1 = [(80, -.5),(0, 7.5),(0, h),(80, h)]
fig, axs = plot_bed(x, y2, s4)
axs.add_patch(Polygon(xy1, facecolor='blue', edgecolor='none', alpha=.25))
fig.savefig(os.path.join(root, 'grains_deposition2.pdf'))

xy1 = [(0, -.5),(80, 7.5),(80, h),(0, h)]
fig, axs = plot_bed(x, y, .25*s1+.75*s2)
axs.add_patch(Polygon(xy1, facecolor='blue', edgecolor='none', alpha=.25))
fig.savefig(os.path.join(root, 'grains_waterlevel.pdf'))

L = 10.
a = 2.
wlx = x[:1,:]
xl = np.maximum(0., 30. - x) / 30.
wl = h + a * np.sin(wlx / L * 2 * np.pi) * xl[:1,:]
xy2 = np.concatenate((wlx, wl), axis=0).T
xy2 = np.concatenate((xy2, xy1[2::-1]))
s5 = (.25+.75*xl)*s1 + .75*(1.-xl)*s2
fig, axs = plot_bed(x, y, s5)
axs.add_patch(Polygon(xy2, facecolor='blue', edgecolor='none', alpha=.25))
fig.savefig(os.path.join(root, 'grains_wave.pdf'))

fig, axs = plot_bed(x, y, s5)
axs.add_patch(Polygon(xy2, facecolor='blue', edgecolor='none', alpha=.25))
for i in np.arange(0,9,1.5):
    axs.plot([0,80], [-.5+i,7.5+i], '-r')
for i in np.arange(0,81,10):
    axs.plot([i,i], [-.5+.1*i,7.+.1*i], '-r')
axs.add_patch(Polygon([(60,7.),
                       (70,8.),
                       (70,9.5),
                       (60,8.5)], facecolor='r', edgecolor='none', alpha=.5))

xx = np.arange(-10,10,.1)
ax2 = fig.add_axes([.775,.2,.1,.2])
ax2.fill_between(xx, np.exp(-xx**2), color='r')
ax2.plot([-10, 10], [.4, .4], '-b', linewidth=3)
#ax2.annotate('moisture content', xy=(-2.,.2), color='b', fontweight='bold', fontsize=6, va='bottom')
ax2.set_xlim((-2,2))
ax2.set_ylim((0,1.))
ax2.set_xticks(())
ax2.set_yticks(())

plt.show()

c = ax2.transAxes.transform((0.,1.))
c = axs.transData.inverted().transform(c)
axs.annotate('', xy=c, xytext=(65,8.25), arrowprops={'arrowstyle':'->', 'shrinkB':0})

fig.savefig(os.path.join(root, 'grains_grid.pdf'))

# %%
import matplotlib.patches

x, y = [0,50,80], [-.5,9.5,12.]

fig, axs = plt.subplots(2, 1, figsize=(10,4))

for ax in axs:
    ax.plot(x, y, '-k', linewidth=3.)
    ax.set_xlim((0,80))
    ax.set_ylim((-1,20))
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_axis_off()

y0 = 2.
x0 = np.interp(y0, y, x)
xy1 = [(0, -.5),(x0, y0),(0, y0)]
axs[0].add_patch(Polygon(xy1, facecolor='blue', edgecolor='none', alpha=.25))

xt = [x0,50,55,80]
yt = np.interp(xt, x, y)
p1 = axs[0].plot(xt, yt + np.asarray([0,7,1,2]), '--r')

ya = np.interp([40,60], x, y)
arw = matplotlib.patches.FancyArrowPatch(posA=(40,ya[0]), posB=(60,ya[1]),
                                         mutation_scale=25., shrinkA=10., shrinkB=10.,
                                         arrowstyle='fancy', color='r')
arw.set_connectionstyle('arc3', rad=-.7)
axs[0].add_patch(arw)

axs[0].set_title('low tide')
axs[0].annotate('temporary deposition\nat berm flat', xy=(50,20),
                xytext=(50,0), textcoords='offset points',
                color='r', ha='left', va='top')

y0 = 9.5
x0 = np.interp(y0, y, x)
xy1 = [(0, -.5),(x0, y0),(0, y0)]
axs[1].add_patch(Polygon(xy1, facecolor='blue', edgecolor='none', alpha=.25))

xt = [x0,80]
yt = np.interp(xt, x, y)
axs[1].plot(xt, yt + np.asarray([0,2]), '--r')

ya = np.interp([60,80], x, y)
arw = matplotlib.patches.FancyArrowPatch(posA=(60,ya[0]), posB=(80,ya[1]),
                                         mutation_scale=25., shrinkA=10., shrinkB=10.,
                                         arrowstyle='fancy', color='r')
arw.set_connectionstyle('arc3', rad=-.5)
axs[1].add_patch(arw)

axs[1].set_title('high tide')
axs[1].annotate('entrainment of\ntemporary deposits', xy=(70,20),
                xytext=(-50,0), textcoords='offset points',
                color='r', ha='right', va='top')

axs[1].legend(p1, ('sediment transport rate',), loc='lower right', frameon=False)

fig.savefig('/Users/hoonhout/Checkouts/PhD/Journals/fielddata/temporal_deposits.pdf')

# %%
import scipy.interpolate

gaussian = lambda x, mu, sigma: np.exp(-(x-mu)**2/sigma**2)

d50 = 10**np.linspace(np.log10(10), np.log10(1000), 100) * 1e-6
m = gaussian(d50, 300e-6, 200e-6) / 100.
uth = 100. * np.sqrt(9.81 * d50 * (2650. - 1.25)/2650.)
u = 8.
q = 1.5e-4 * (u - uth)**3

mx1 = []
mx2 = []

n = 200
fig, axs = subplots(2, 1, figsize=(8,6), sharex=True)
axs = np.asarray([[axs[0], axs[0].twinx()],
                  [axs[1], axs[1].twinx()]])
for i in range(n):
    p = m/np.sum(m)
    if np.mod(i, 30) == 0:
        c = 1. - i/float(n)
        lw = 5.*i/n
        #h1 = axs[0,1].plot(d50*1e6, p, color=(c,c,c), linewidth=lw, label='sediment in bed')
        axs[0,0].fill_between(d50*1e6, np.zeros(d50.shape), p, facecolor=(c,c,1.), edgecolor='none')
        axs[1,0].fill_between(d50*1e6, np.zeros(d50.shape), q * p, facecolor=(1.,c,c), edgecolor='none')
        mx1.append((d50[np.argmax(p)], np.max(p)))
        mx2.append((d50[np.argmax(q*p)], np.max(q*p)))
    m = np.maximum(0., m - q * p)
    
o = .02
axs[0,0].annotate('time', xy=(mx1[1][0]*1e6, 1.5*o+mx1[1][1]), color='b', rotation=30, ha='left', va='bottom')
axs[0,0].annotate('', xy=(mx1[-1][0]*1e6, o+mx1[-1][1]), xytext=(mx1[1][0]*1e6, o+mx1[1][1]), 
                  color='b', arrowprops={'arrowstyle':'->', 'shrinkB':0, 'linewidth':3, 'color':'b'})

o = 2e-5
axs[1,0].annotate('time', xy=(mx2[1][0]*1e6, .25*o+mx2[1][1]), color='r', rotation=-45, ha='left', va='bottom')
axs[1,0].annotate('', xy=(mx2[-1][0]*1e6, o+mx2[-1][1]), xytext=(mx2[1][0]*1e6, o+mx2[1][1]), 
                  color='r', arrowprops={'arrowstyle':'->', 'shrinkB':0, 'linewidth':3, 'color':'r'})

for ax in axs[:,1]:
    h1 = ax.plot(d50*1e6, q, '-g', linewidth=3., label='equilibrium sediment transport')
    ax.set_ylim((0,.05))
    
for ax in axs[:,0]:
    ax.grid()

for ax in axs.flatten():
    ax.set_yticks(())

axs[1,0].set_xlabel('grain size [$\mathrm{\mu m}$]')
axs[0,0].set_ylim((0,.35))
axs[1,0].set_ylim((0,2e-4))

h2 = matplotlib.patches.Patch(color='b', label='normalized sediment availibility')
h3 = matplotlib.patches.Patch(color='r', label='sediment transport')
axs[0,0].legend(handles=(h1[0],h2,h3), loc='upper right')

fig.savefig('/Users/hoonhout/Checkouts/PhD/Conferences/NCK2016/transport.pdf')

# %%
mx1
# Out:
# [(0.000298364724028334, 0.028457351109902111),
#  (0.00034304692863149192, 0.052559111206470444),
#  (0.00039442060594376563, 0.072392942353167469),
#  (0.00043287612810830614, 0.091625492305697442),
#  (0.00047508101621027978, 0.11114786939249882),
#  (0.00049770235643321133, 0.13061059334552783),
#  (0.00052140082879996842, 0.14912330855428177)]
