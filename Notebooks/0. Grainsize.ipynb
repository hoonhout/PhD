# %%
# %%capture

import netCDF4

fig, axs = subplots(3, 1, figsize=(10,12))

# %%
import cPickle as pickle

with open('/Users/hoonhout/Checkouts/Zandmotor/morphology/JETSKI/bathy_gridded.pkl', 'r') as fp:
    grid = pickle.load(fp)

# %% [markdown]
# # Vlugtenburg

# %%
p_x = np.asarray([-190.0, -185.0, -180.0, -175.0, -170.0, -165.0,                                                                                                                    
-160.0, -155.0, -150.0, -145.0, -140.0, -135.0, -130.0, -125.0,                                                                                                                      
-120.0, -115.0, -110.0, -105.0, -100.0, -95.0, -90.0, -85.0, -80.0,                                                                                                                  
-75.0, -70.0, -65.0, -60.0, -55.0, -50.0, -45.0, -40.0, -35.0, -30.0,                                                                                                                
-25.0, -20.0, -15.0, -10.0, -5.0, 0.0, 5.0, 10.0, 15.0, 20.0, 25.0,                                                                                                                  
30.0, 35.0, 40.0, 45.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0,                                                                                                                    
85.0, 90.0, 95.0, 100.0, 105.0, 110.0, 115.0, 120.0, 125.0, 130.0,                                                                                                                   
135.0, 140.0, 145.0, 150.0, 155.0, 160.0])                                                                                                                                           
                                                                                                                                                                                     
p_z = np.asarray([5.844899646966327, 5.095857443315468,                                                                                                                              
4.57938936510925, 4.295151859618338, 3.884130737104755,                                                                                                                              
3.589728878255555, 3.426078768481355, 3.26242865870922,                                                                                                                              
3.116946123859333, 2.99798708926256, 2.872458642358513,                                                                                                                              
2.767329797923865, 2.684135344324336, 2.6507180925615,                                                                                                                               
2.6688450147704, 2.707307094908424, 2.772870729009586,                                                                                                                               
2.83843436310952, 2.90399799721068, 2.96956163131185,                                                                                                                                
3.03512526541178, 3.09984461820269, 3.112557466761847,                                                                                                                               
3.19448392582566, 3.325946145620179, 3.76106432250853,                                                                                                                               
4.239862346780472, 4.600750499484771, 4.84963566249834,                                                                                                                              
5.040134882939729, 5.124534290333683, 5.14180207592129,                                                                                                                              
5.047772860787438, 4.95639784217276, 4.887776207167068,                                                                                                                              
4.77449797923488, 4.67665636875385, 4.562777862834489,                                                                                                                               
4.474264598618341, 4.41318629461666, 4.35210799061397,                                                                                                                               
4.310724289388289, 4.21329356931928, 4.109067494161436,                                                                                                                              
4.061548751212178, 3.939391500620375, 3.77520306388697,                                                                                                                              
3.662038134510947, 3.553307530521316, 3.43316000069978,                                                                                                                              
3.323845759429099, 3.203902465617444, 3.06919871877319,                                                                                                                              
2.92700168101529, 2.801692636740359, 2.706194536470485,                                                                                                                              
2.616549360406687, 2.451614953754237, 2.310449296899673,                                                                                                                             
2.22274989868216, 2.0818031771102, 1.95683311559313, 1.91656107191474,                                                                                                               
1.78994251148432, 1.510233129751942, 1.29577152302569,                                                                                                                               
1.1039834487851, 0.917754675293345, 0.80244108479458,                                                                                                                                
0.667259220456622, 0.580207659793645])

# columns: top, 0.5m deep, top 5m N, top 5m landward, top 5m S
d50 = np.asarray([[262, 208, 246, 262],  # RSP58
                  [208, 196, 246, 231],  # 40 m landward
                  [277, 208, 277, 292],  # 80 m landward
                  [196, 223, 196, 215],  # 120 m landward
                  [215, 215, 200, 238],  # 160 m landward
                  [238, 269, 311, 389],  # 194 m landward
                  [285,  -1,  -1,  -1],  # 199 m landward
                  [246, 223, 246, 246],  # 40 m seaward
                  [231, 277, 231, 367],  # 80 m seaward
                  [223, 269, 215, 254],  # 120 m seaward
                  [322,  -1, 322, 262]], dtype=double) # 160 m seaward

x = np.asarray([0, -40, -80, -120, -160, -194, -199, 40, 80, 120, 160])

ix = sorted(range(len(x)), key=lambda i: x[i])

d50[d50<0.] = np.nan

ax = axs[2]
ax = [ax.twinx(), ax]
p1 = ax[0].plot(p_x, p_z, ':k', label='beach profile')[0]
p2 = ax[1].plot(x[ix], d50[ix,0], '-or', markeredgecolor='r', zorder=100, label='surface grain size')[0]
p3 = ax[1].plot(x[ix], d50[ix,1], '-sk', zorder=50, label='grain size at 0.5m below surface')[0]
ax[1].plot([120., 120.], [0., 350.], '--k')
ax[1].annotate('high water mark', (100, 350), xytext=(10,-10), textcoords='offset points', va='top', ha='left')
ax[1].annotate('sea side', (0, -19), xycoords='axes pixels', va='top', ha='left')
ax[1].annotate('land side', (560, -19), xycoords='axes pixels', va='top', ha='right')
ax[1].set_xlim((-200, 160))
ax[1].set_ylim((100, 350))
ax[1].set_xlabel('cross-shore distance from beach pole [$\mathrm{m}$]')
ax[0].set_ylabel('profile height [$\mathrm{m+NAP}$]')
ax[1].set_ylabel('median grain size [$\mathrm{\mu m}$]')
ax[1].invert_xaxis()
ax[1].grid(axis='y')

#legends = (p1, p2, p3)
#ax[1].legend(legends, [l.get_label() for l in legends], loc='lower right')
ax[1].set_title('Vlugtenburg')

#fig.savefig('/Users/hoonhout/Checkouts/PhD/Journals/grainsize/grainsize_vlugtenburg.pdf')

# %% [markdown]
# # Kijkduin

# %%
nc = netCDF4.Dataset('http://opendap.deltares.nl/thredds/dodsC/opendap/rijkswaterstaat/jarkus/profiles/transect.nc', 'r')
dt = netCDF4.num2date(nc.variables['time'][:], nc.variables['time'].units)
ix = np.where(nc.variables['id'][:] == 9010592)[0][0]
p_z = nc.variables['altitude'][-2,ix,:]
p_x = nc.variables['cross_shore'][~p_z.mask]
p_z = p_z[~p_z.mask]
nc.close()

x = np.asarray([0, 5.6389, 13.0720, 25.9520, 76.8303, 121.2099])

d50 = np.asarray([[0.4422, 0.3968, 0.4525, 0.3606, 0.3027, 0.2681],
                  [0.3405, 0.3505, 0.3612, 0.3333, 0.2906, 0.2579]]).T * 1000.

ax = axs[0]
ax = [ax.twinx(), ax]
p1 = ax[0].plot(p_x, p_z, ':k', label='cross-shore beach profile')[0]
p2 = ax[1].plot(100-x, d50[:,0], '-or', markeredgecolor='r', zorder=100, label='surface grain size')[0]
p3 = ax[1].plot(100-x, d50[:,1], '-sk', zorder=50, label='grain size below surface')[0]
ax[1].plot([90., 90.], [100., 500.], '--k')
ax[1].annotate('high water mark', (90, 500), xytext=(10,-10), textcoords='offset points', va='top', ha='left')
#ax[1].annotate('sea side', (0, -19), xycoords='axes pixels', va='top', ha='left')
#ax[1].annotate('land side', (560, -19), xycoords='axes pixels', va='top', ha='right')
ax[1].set_xlim((-50, 120))
ax[0].set_ylim((0, 12))
ax[1].set_ylim((100, 500))
#ax[1].set_xlabel('cross-shore distance from beach pole [$\mathrm{m}$]')
ax[0].set_ylabel('profile height [$\mathrm{m+NAP}$]')
ax[1].set_ylabel('median grain size [$\mathrm{\mu m}$]')
ax[1].invert_xaxis()
ax[1].grid(axis='y')

legends = (p1, p2, p3)
ax[1].legend(legends, [l.get_label() for l in legends], loc='upper right')

ax[1].set_title('Kijkduin')

#fig.savefig('/Users/hoonhout/Checkouts/PhD/Journals/grainsize/grainsize_kijkduin.pdf')

# %% [markdown]
# # Zandmotor

# %%
nc = netCDF4.Dataset('http://opendap.deltares.nl/thredds/dodsC/opendap/rijkswaterstaat/jarkus/profiles/transect.nc', 'r')
dt = netCDF4.num2date(nc.variables['time'][:], nc.variables['time'].units)
ix = np.where(nc.variables['id'][:] == 9010883)[0][0]
p_z = nc.variables['altitude'][-2,ix,:]
p_x = nc.variables['cross_shore'][~p_z.mask]
p_z = p_z[~p_z.mask]
nc.close()

x = np.asarray([0, 30., 50, 100, 200, 400])

d50 = np.asarray([[0.3713, 0.3545, 0.3919, 0.3471, 0.6648, 0.4120],
                  [0.3334, 0.3359, 0.2595, 0.3019, 0.3726, -1]]).T * 1000.

d50[d50<0.] = np.nan

ax = axs[1]
ax = [ax.twinx(), ax]
p1 = ax[0].plot(p_x, p_z, ':k', label='beach profile')[0]
p2 = ax[1].plot(950-x, d50[:,0], '-or', markeredgecolor='r', zorder=100, label='surface grain size')[0]
p3 = ax[1].plot(950-x, d50[:,1], '-sk', zorder=50, label='grain size below surface')[0]
ax[1].plot([910., 910.], [100., 1000.], '--k')
ax[1].annotate('high water mark', (910, 800), xytext=(10,-10), textcoords='offset points', va='top', ha='left')
#ax[1].annotate('sea side', (0, -19), xycoords='axes pixels', va='top', ha='left')
#ax[1].annotate('land side', (560, -19), xycoords='axes pixels', va='top', ha='right')
ax[1].set_xlim((550, 950))
ax[0].set_ylim((0, 5))
ax[1].set_ylim((100, 800))
#ax[1].set_xlabel('cross-shore distance from beach pole [$\mathrm{m}$]')
ax[0].set_ylabel('profile height [$\mathrm{m+NAP}$]')
ax[1].set_ylabel('median grain size [$\mathrm{\mu m}$]')
ax[1].invert_xaxis()
ax[1].grid(axis='y')

#legends = (p1, p2, p3)
#ax[1].legend(legends, [l.get_label() for l in legends], loc='lower right')
ax[1].set_title('Sand Motor')

#fig.savefig('/Users/hoonhout/Checkouts/PhD/Journals/grainsize/grainsize_zandmotor.pdf')

# %%
fig.savefig('/Users/hoonhout/Checkouts/PhD/Journals/grainsize/grainsize_all.pdf')

# %%
def get_transport_reduction(u, f,
                            A=100., rho_p=2650., rho_a=1.25, g=9.81,
                            d_n=np.arange(200e-6, 455e-6, 10e-6)):
    
    f = sqrt(f)
    d_n, u = np.meshgrid(d_n, u)

    uth_1 = A * np.sqrt((rho_p-rho_a)/rho_p*g*d_n)
    uth_2 = A * np.sqrt((rho_p-rho_a)/rho_p*g*f*d_n)

    q_1 = np.maximum(0., u - uth_1)**3
    q_2 = np.maximum(0., u - uth_2)**3

    r = (1 - q_2 / q_1) * 100.
    r[np.isnan(r)] = 100.
    
    return r


def lines_to_polygon(u, r):

    x = np.concatenate((u[:], u[-1:0:-1]))
    y = np.concatenate((np.min(r, axis=1),
                        np.max(r, axis=1)[-1:0:-1]))
    xy = np.concatenate((x[:,np.newaxis], y[:,np.newaxis]), axis=1)
    
    return xy


u = np.arange(0., 41., .1)

fig, axs = subplots()

for i, f in enumerate(np.arange(1.1, 2.1, .1)):
    r = get_transport_reduction(u, f).mean(axis=1)
    axs.plot(u, r, '-r', linewidth=2)
    ul = 5.+1.5*i
    axs.annotate('%d%%' % ((f-1)*100), xy=(ul, np.interp(ul, u, r)), fontsize=8,
                 ha='center', va='center', backgroundcolor='w', rotation=0)

r = np.concatenate((get_transport_reduction(u, 1.1),
                    get_transport_reduction(u, 2.0)), axis=1)
xy = lines_to_polygon(u, r)
axs.add_artist(plt.Polygon(xy, alpha=.5, zorder=-1, closed=True, facecolor='none', edgecolor='none', hatch='////'))

axs.set_xlim((0, 20))
axs.set_ylim((0, 101))
axs.set_xlabel('wind velocity [$\mathrm{m/s}$]')
axs.set_ylabel('transport reduction [$\mathrm{\%}$]\n$\Delta q = q_{eq,2} / q_{eq,1} \cdot 100\%$')
axs.set_xticks(np.arange(0, 21, 5))
axs.grid()

fig.savefig('/Users/hoonhout/Checkouts/PhD/Journals/grainsize/transport_reduction.pdf')

# %% [markdown]
# # TNO

# %%
import re
import pandas as pd

fname = '/Users/hoonhout/Checkouts/Zandmotor/morphology/sediment_composition/Data_T0_1993to2001_TNO/TNOdata.txt'

with open(fname, 'r') as fp:
    
    data = []
    for i, row in enumerate(fp):
        row = re.split('\t', row)
        if i == 0:
            columns = row
        else:
            for j, col in enumerate(row):
                if re.match('^[-]+$', col):
                    row[j] = np.nan
                elif re.match('^-?[0-9]+$', col):
                    row[j] = int(col)
                elif re.match('^-?[0-9\.]+$', col):
                    row[j] = float(col)
            r = [np.nan] * len(columns)
            r[:(j+1)] = row
            data.append(r)
            
    df_tno = pd.DataFrame(data, columns=columns)

# %%
import pyproj
import matplotlib.path
import matplotlib.patches

bbox = matplotlib.path.Path(((71500, 450750),
                             (74500, 450750),
                             (74500, 453750),
                             (71500, 453750)))

p1 = pyproj.Proj(proj='utm', zone=31, ellps='WGS84')
p2 = pyproj.Proj(init='epsg:28992')

locs = [pyproj.transform(p1, p2, xi, yi) for xi, yi in zip(df_tno['UTM_X'], df_tno['UTM_Y'])]
df_tno['RD_X'], df_tno['RD_Y'] = zip(*locs)
idx = np.asarray(bbox.contains_points(locs))

fig, axs = subplots()
axs.scatter(*zip(*locs))
axs.add_patch(matplotlib.patches.PathPatch(bbox, alpha=.1))
axs.set_xlim((71000, 75000))
axs.set_ylim((450000, 455000))
axs.set_aspect('equal')

np.sum(idx)
# Out:
# 6

# %%
df_tno_f = df_tno.filter(regex='^F\d+').fillna(0.).iloc[idx]
df_tno_f.columns = [np.mean([float(x) for x in re.match('^F(\d+)-(\d+)', ix).groups()]) for ix in df_tno_f.columns]

df_tno_cs = np.cumsum(df_tno_f, axis=1)
d50 = 10**(np.interp(50, df_tno_cs.mean(axis=0), np.log10(df_tno_cs.columns)))

fig, axs = subplots()
axs.plot(df_tno_cs.columns, df_tno_cs.T, '-k', alpha=.1);
axs.plot(df_tno_cs.columns, df_tno_cs.mean(axis=0), '-or');
axs.annotate('$\mathrm{d_{50} = %d}$' % d50, xy=(d50, 50),
             ha='center', va='center', bbox={'boxstyle':'round,pad=.3', 'facecolor':'w'})
axs.set_xlim((10, 1000))
axs.set_ylim((0, 100))
axs.set_yticks((0, 10, 30, 50, 60, 90, 100))
axs.set_ylabel('percentile [%]')
axs.set_xlabel('grain size [$\mathrm{\mu m}$]')
axs.set_xscale('log')
axs.grid()

# %%
x, y = df_tno['RD_X'].iloc[idx], df_tno['RD_Y'].iloc[idx]

fig, axs = subplots()
axs.contour(grid['X'], grid['Y'], grid['Z']['20110803'], [1.], colors='k')
axs.scatter(x, y, c=[np.average(df_tno_f.columns, weights=df_tno_f.ix[c]) for c in df_tno_f.index], alpha=1., cmap='Reds')
axs.set_aspect('equal')
axs.set_xlim((71500, 74500))
axs.set_ylim((450750, 453750))
# Out:
# (450750, 453750)

# %% [markdown]
# # Imares

# %%
import os
import netCDF4

root = 'https://bashoonhout:Rf3QyUs4@zandmotordata.nl/thredds/dodsC/opendap/morphology/sediment_composition/'
fnames = ['sedimentsampling_sandmotor_oct2010.nc',
         'sedimentsampling_sandmotor_aug2012.nc',
         'sedimentsampling_sandmotor_oct2013.nc']

p = [10, 30, 50, 60, 90]

dfs = []
for fname in fnames:
    with netCDF4.Dataset(os.path.join(root, fname)) as ds:
        t = ds.variables['type'][:]
        idx = (t[:,0] == 'S') #| (t[:,0] == 'D')
    
        x = ds.variables['x'][idx]
        y = ds.variables['y'][idx]
        
        d = np.zeros((5, np.sum(idx)))
        for i, pi in enumerate(p):
            d[i,:] = ds.variables['D%d' % pi][idx]

    idx = np.asarray(bbox.contains_points(zip(x,y)))
    
    year = np.asarray([int(re.sub('\D', '', fname))] * len(x))
    data = np.concatenate((year.reshape((1,-1)),
                           x.reshape((1,-1)),
                           y.reshape((1,-1)), d), axis=0).T
    
    df = pd.DataFrame(data, columns=['year', 'x', 'y'] + p).set_index(['year', 'x', 'y'])    
    dfs.append(df)
    
df_imares = pd.concat(dfs)

# %% [markdown]
# # Boskalis

# %%
data = np.asarray(
    [[149,278,309,479],
     [165,283,312,477],
     [181,316,353,555],
     [150,286,316,480],
     [154,285,317,480],
     [152,272,298,449],
     [145,276,306,464],
     [145,282,317,506],
     [144,265,292,432],
     [139,263,295,465],
     [142,259,286,430],
     [141,266,298,461],
     [143,258,287,451],
     [159,283,314,476],
     [134,261,291,456],
     [127,224,252,408],
     [129,251,281,444],
     [139,281,318,587],
     [224,399,448,760],
     [164,283,312,469],
     [151,280,311,470],
     [151,268,296,447],
     [145,273,301,469],
     [155,284,311,469],
     [154,278,306,459]])

df_boskalis = pd.DataFrame(data, columns=[10, 50, 60, 90])

fig, axs = subplots()
axs.plot(df_boskalis.T, df_boskalis.columns, '-k', alpha=.1)
axs.plot(df_boskalis.mean(axis=0), df_boskalis.columns, '-or')
axs.set_xlim((100, 1000))
axs.set_ylim((0, 100))
axs.set_xscale('log')
axs.set_yticks((0, 10, 30, 50, 60, 90, 100))
axs.grid()

# %% [markdown]
# # NEMO

# %%
root = '/Users/hoonhout/Checkouts/Zandmotor/morphology/sediment_composition/MacroPhotography_NEMO/raw/sieve/'
fnames = ['20130221_Zandmotor/Feb212013SandSamplesDataProcess.xlsx',
          '20130822_Zandmotor/2013 08 22 SM surface sieve data process.xlsx']

dfs = []
for fname in fnames:
    df = pd.read_excel(os.path.join(root, fname), header=3, parse_cols=range(2,10))
    df.columns = [float(x) * 1000. if re.match('^[\d\.]+$', str(x)) else x for x in df.columns]
    df = df.ix[4::5].interpolate(axis=1)
    df['month'] = [fname[:6]] * len(df)
    dfs.append(df.set_index('month', append=True))
    
df_nemo = pd.concat(dfs)

# %% [markdown]
# # Overview

# %%
fig, axs = subplots()
axs.plot(df_tno_cs.columns, df_tno_cs.mean(axis=0), '-ob')
axs.plot(df_boskalis.mean(axis=0), df_boskalis.columns, '-og')
for year in df_nemo.index.levels[1]:
    axs.plot(df_nemo.columns, df_nemo.xs(year, level=1).mean(axis=0), '-oy')
for year in df_imares.index.levels[0]:
    axs.plot(df_imares.xs(year, level=0).mean(axis=0), df_imares.columns, '-or')

axs.set_xlim((100, 1000))
axs.set_ylim((0, 100))
axs.set_yticks([0, 10, 30, 50, 60, 90, 100])
axs.set_ylabel('percentile [%]')
axs.set_xlabel('grain size [$\mathrm{\mu m}$]')
axs.set_xscale('log')
axs.grid()

# %%
from datetime import datetime
import matplotlib.dates

g = df_imares.groupby(level=0).mean()
years = [datetime.strptime(str(int(x)), '%Y') for x in g.index]
ordinals = [y.toordinal() for y in years]

fig, axs = subplots(1, 2, figsize=(10,4), gridspec_kw={'width_ratios':[2,1]})

poly1 = zip(ordinals, g[30]) + zip(ordinals, g[60])[::-1]
poly2 = zip(ordinals, g[10]) + zip(ordinals, g[90])[::-1]
axs[0].add_patch(matplotlib.patches.Polygon(poly1, facecolor='k', alpha=.2, label='$\mathrm{D_{30} - D_{60}}$'))
axs[0].add_patch(matplotlib.patches.Polygon(poly2, facecolor='k', alpha=.1, label='$\mathrm{D_{10} - D_{90}}$'))
axs[0].plot(years, g[50], '-k', linewidth=2, label='$\mathrm{D_{50}}$')
axs[0].set_xlabel('time [years]')
axs[0].set_ylabel('grain size [$\mathrm{\mu m}$]')
axs[0].set_ylim((100, 1000))
axs[0].set_yscale('log')
axs[0].grid(which='both')
axs[0].legend(loc='lower right')
axs[0].xaxis.set_major_locator(matplotlib.dates.YearLocator())

n = float(len(df_imares.index.levels[0])-1)
for i, year in enumerate(df_imares.index.levels[0]):
    axs[1].plot(df_imares.columns, df_imares.xs(year, level=0).mean(axis=0), '-ok', alpha=.2+.8*i/n, label=int(year))
axs[1].set_ylim((100, 1000))
axs[1].set_xlim((0, 100))
axs[1].set_xticks([0, 10, 30, 50, 60, 90, 100])
axs[1].set_xlabel('percentile [%]')
axs[1].set_yscale('log')
axs[1].set_yticklabels(())
axs[1].grid(which='both')
axs[1].legend(loc='lower right')

fig.savefig('/Users/hoonhout/Checkouts/PhD/Journals/fielddata/grainsize.pdf')
